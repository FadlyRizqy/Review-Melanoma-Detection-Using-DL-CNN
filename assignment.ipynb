# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
#
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPool2D, Dropout,BatchNormalization
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %% [markdown]
# Data has been downloaded and stored in a folder 'images' divided into 'train' and 'test' folder.

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("images\Train")
data_dir_test = pathlib.Path('images\Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split=0.2,
  subset="training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split=0.2,
  subset="validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
#
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
plt.figure(figsize=(10,10))
for i in range(9):
  plt.subplot(3,3,i+1)
  image = plt.imread(
      str(list(data_dir_train.glob(f'{class_names[i]}/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)
  plt.axis('off')

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
#
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use `layers.experimental.preprocessing.Rescaling` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
model = Sequential()
model.add(layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3)))
model.add(Conv2D(32, kernel_size=(3, 3),padding = 'Same',activation= 'relu'))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, kernel_size=(3, 3),padding = 'Same',activation ='relu'))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, kernel_size=(3, 3),padding = 'Same',activation ='relu'))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, kernel_size=(3, 3),padding = 'Same',activation ='relu'))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(Conv2D(16, kernel_size=(7, 7),padding = 'Same',activation= 'relu'))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, kernel_size=(11,11),padding = 'Same',activation ='relu'))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(256, kernel_size=(3, 3),padding = 'Same',activation ='relu'))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(9,activation='softmax'))

# %% [markdown]
# ### Compile the model
#
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-7)
opt=tf.keras.optimizers.Adam()
model.compile(optimizer=opt,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 90, 90, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 90, 90, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 45, 45, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 22, 22, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 11, 11, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 16)        50192
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 16)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 5, 16)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 5, 5, 128)         247936
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2, 2, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 2, 2, 256)         295168
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 1161
# =================================================================
# Total params: 720,601
# Trainable params: 720,601
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
              callbacks=[learn_control]
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 8s 35ms/step - loss: 2.0722 - accuracy: 0.1875 - val_loss: 2.0715 - val_accuracy: 0.2058
# Epoch 2/20
# 56/56 [==============================] - 1s 22ms/step - loss: 2.0195 - accuracy: 0.2026 - val_loss: 1.9863 - val_accuracy: 0.1924
# Epoch 3/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.9896 - accuracy: 0.2271 - val_loss: 1.9625 - val_accuracy: 0.2438
# Epoch 4/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.8601 - accuracy: 0.2879 - val_loss: 1.7884 - val_accuracy: 0.2886
# Epoch 5/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.8238 - accuracy: 0.3041 - val_loss: 1.8707 - val_accuracy: 0.3087
# Epoch 6/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.7499 - accuracy: 0.3343 - val_loss: 1.7215 - val_accuracy: 0.3468
# Epoch 7/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.6556 - accuracy: 0.4007 - val_loss: 2.0171 - val_accuracy: 0.2349
# Epoch 8/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.6447 - accuracy: 0.4035 - val_loss: 1.5469 - val_accuracy: 0.4452
# Epoch 9/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.5590 - accuracy: 0.4442 - val_loss: 1.5094 - val_accuracy: 0.4787
# Epoch 10/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.4785 - accuracy: 0.4860 - val_loss: 1.4281 - val_accuracy: 0.4944
# Epoch 11/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.4819 - accuracy: 0.4794 - val_loss: 1.4971 - val_accuracy: 0.4877
# Epoch 12/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.3941 - accuracy: 0.5073 - val_loss: 1.4027 - val_accuracy: 0.5235
# Epoch 13/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.3636 - accuracy: 0.5257 - val_loss: 1.5480 - val_accuracy: 0.4474
# Epoch 14/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.3934 - accuracy: 0.5140 - val_loss: 1.4512 - val_accuracy: 0.4989
# Epoch 15/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.3130 - accuracy: 0.5446 - val_loss: 1.4296 - val_accuracy: 0.4966
# Epoch 16/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.3252 - accuracy: 0.5279 - val_loss: 1.4728 - val_accuracy: 0.4989
# Epoch 17/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.3460 - accuracy: 0.5117 - val_loss: 1.4142 - val_accuracy: 0.5123
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 18/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.2183 - accuracy: 0.5552 - val_loss: 1.3295 - val_accuracy: 0.5324
# Epoch 19/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.1737 - accuracy: 0.5658 - val_loss: 1.3349 - val_accuracy: 0.5436
# Epoch 20/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.1424 - accuracy: 0.5882 - val_loss: 1.3489 - val_accuracy: 0.5369

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# **Findings**
#
# 1. The Traing accuracy and validation accuracy are almost same, but very low which indicates that the model is underfitting
# 2. Training loss is very low, but validation loss is fluctuating.
#
# Thus we can collect that the model is not good.

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# augumentation strategy with flip,rotate,skew,shift, zoom, brightness, contrast, saturation, hue
data_augmentation = tf.keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.2),
    layers.experimental.preprocessing.RandomZoom(0.2),
    layers.experimental.preprocessing.RandomContrast(0.1)
  ]
)

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ### Todo:
#
# ### Create the model, compile and train the model

# %%
model = Sequential()

model.add(layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3)))
model.add(data_augmentation)
model.add(Conv2D(32, kernel_size=(3, 3),padding = 'Same',activation= 'relu'))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, kernel_size=(3, 3),padding = 'Same',activation ='relu'))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, kernel_size=(3, 3),padding = 'Same',activation ='relu'))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, kernel_size=(3, 3),padding = 'Same',activation ='relu'))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(Conv2D(16, kernel_size=(7, 7),padding = 'Same',activation= 'relu'))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, kernel_size=(11, 11),padding = 'Same',activation ='relu'))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(256, kernel_size=(3, 3),padding = 'Same',activation ='relu'))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(9,activation='softmax'))

# %% [markdown]
# ### Compiling the model

# %%
### Todo, choose an appropirate optimiser and loss function
learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-7)
opt=tf.keras.optimizers.Adam()
model.compile(optimizer=opt,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 180, 180, 32)      896
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 90, 90, 32)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 90, 90, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 90, 90, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 45, 45, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 45, 45, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 45, 45, 64)        36928
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 22, 22, 64)        36928
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 11, 11, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 11, 11, 16)        50192
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 5, 5, 16)          0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 5, 5, 16)          0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 5, 5, 128)         247936
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 2, 2, 128)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 2, 2, 256)         295168
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None,
ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 19/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.3379 - accuracy: 0.5257 - val_loss: 1.4299 - val_accuracy: 0.5168
# Epoch 20/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.3038 - accuracy: 0.5340 - val_loss: 1.3918 - val_accuracy: 0.5190

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?
#
# **Findings**
#
# 1. The Training accuracy and validation accuracy are almost same. This is a sign of good fit but the accuracy is still very low. The model requires more epochs to train with class imbalance handled.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
#
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
# images in each classes
class_diff=pd.DataFrame()
for i in range(len(class_names)):
  name= class_names[i]
  number = len(list(data_dir_train.glob(f'{class_names[i]}/*.jpg')))
  class_diff=class_diff.append({'class':name,'number':number},ignore_index=True)

class_diff
# Out:
#                         class  number
# 0           actinic keratosis   114.0
# 1        basal cell carcinoma   376.0
# 2              dermatofibroma    95.0
# 3                    melanoma   438.0
# 4                       nevus   357.0
# 5  pigmented benign keratosis   462.0
# 6        seborrheic keratosis    77.0
# 7     squamous cell carcinoma   181.0
# 8             vascular lesion   139.0

# %%
class_diff.plot.bar(x='class',y='number',rot=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Findings**
#
# #### - Which class has the least number of samples?
#
# #### **Ans.** seborrheic keratosis (77)
#
# #### - Which classes dominate the data in terms proportionate number of samples?
#
# #### **Ans.** pigmented benign keratosis (462)

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
#
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# %conda install -c augmentor augmentor
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
class_names=['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %%
path_to_training_dataset="images/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to images/Train/actinic keratosis\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x23BDF6A6438>: 100%|██████████| 500/500 [00:01<00:00, 327.27 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to images/Train/basal cell carcinoma\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x23BE1ED79E8>: 100%|██████████| 500/500 [00:01<00:00, 281.85 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to images/Train/dermatofibroma\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x23BE1F03A58>: 100%|██████████| 500/500 [00:01<00:00, 268.25 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to images/Train/melanoma\output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x23BDFA20710>: 100%|██████████| 500/500 [00:08<00:00, 60.51 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to images/Train/nevus\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x23BE1ED95C0>: 100%|██████████| 500/500 [00:08<00:00, 58.45 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to images/Train/pigmented benign keratosis\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x23B806B37B8>: 100%|██████████| 500/500 [00:01<00:00, 288.13 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to images/Train/seborrheic keratosis\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x23BE1F003C8>: 100%|██████████| 500/500 [00:03<00:00, 132.07 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to images/Train/squamous cell carcinoma\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x23B806B3F28>: 100%|██████████| 500/500 [00:01<00:00, 294.51 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to images/Train/vascular lesion\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x23B806B89E8>: 100%|██████████| 500/500 [00:01<00:00, 285.97 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
from glob import glob

path_list_new = list(glob(os.path.join(data_dir_train, '*','output', '*.jpg')))
path_list_new
# Out:
# ['images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_14674673-7f4e-45ea-b59a-942a5570b1c3.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_2f5ee5a7-abfe-4446-bfd1-d6eb86d39f4d.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_760e7bd3-8a32-4978-8803-7e29cb27c7ce.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_92967e4b-f09c-47ff-a5df-67c17942cc3f.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025803.jpg_2f63e146-7546-40d1-b926-6aa9f773a97b.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025803.jpg_948c28b1-0cd4-40bf-947a-380b3e21742e.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025803.jpg_cf285cfa-1568-4255-acfa-0553c0e497af.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025803.jpg_d1b1dffd-b5dc-4fa6-ac03-4115d3869d2c.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025803.jpg_e4f8c856-4cdf-4e1f-aba5-93bf8f67af8d.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_716bb941-b36c-4f41-929e-76319be32af2.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_9ee0d78f-e988-4ddb-a69c-0cb75a9756b6.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025825.jpg_d57e6760-2f80-4b7c-ad6a-ad435d99bc4c.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025953.jpg_0be3e1c9-7512-47c2-9895-2aa926ce7c54.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025953.jpg_675fa307-a056-4d57-8716-25a7ff76bb76.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025953.jpg_74b9e110-e43d-4552-87f5-42a32650742a.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025953.jpg_94c1ce34-8da3-4a2b-a6b1-0457d921dfac.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025953.jpg_baf3bb7c-d339-4c72-9cf2-1b74e171372c.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025953.jpg_eb39069a-ad7d-426b-bed4-b3f934d4fe75.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025953.jpg_ed8978dc-3de1-4ce0-8aec-cd91b313bbc3.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025953.jpg_f221e483-e774-428d-b642-7140b7e7394c.jpg',
#  'images\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0
jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031284.jpg_63003e8a-efb2-4fb1-b0a7-4e7ed808931b.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031294.jpg_2bd319ae-fb2b-4a43-ab75-e93e469bc8b7.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031298.jpg_143fa90f-556e-42e3-8744-faa183aa8e13.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031298.jpg_a45cfbf2-f990-47a9-9723-abc7f23275a2.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031318.jpg_502d1036-4a8c-4115-9439-910f375f9676.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031351.jpg_493cc20c-3c6c-46f0-b76a-84a2b9c74c56.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031351.jpg_6e22ad26-88e6-412d-b008-ee219960ca72.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031351.jpg_a93e47f0-e9d4-483a-a173-dd01218a524f.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031351.jpg_cec97b9d-8bda-4b81-862e-7d680f838add.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031378.jpg_1ccf7dd7-6495-43ea-a712-1075b81fd547.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031378.jpg_a44e6f9b-9340-4785-ae3b-139f766935b4.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031384.jpg_3df7ccd9-c9d4-4fc4-85b7-b45586735467.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031407.jpg_735b1a50-31f1-4d82-93e7-2da71c41a82d.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031407.jpg_b0446706-4bcc-4254-9f88-c3f7bccc3fb8.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031413.jpg_091d46d4-3c45-4680-8036-c6f248e7f731.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031413.jpg_8c82dd64-55e0-4993-8a17-9e07f54f146a.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031442.jpg_95ea8b3b-17da-406a-87d7-c446ce79f257.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031450.jpg_d0fd28db-7b21-4e53-a404-a2646f115178.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031489.jpg_9a00942f-5960-4ba6-bd35-fcf1dabea661.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031520.jpg_81f37b6d-b529-4568-a960-ae8026bdc09a.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031526.jpg_9778d556-ad9a-4ce1-a2e5-45b86ab43efe.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031526.jpg_de245995-c1c1-4b0b-a1af-7450b7810853.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031531.jpg_5fa4cc2c-cebb-4c7c-8df9-0bab687e8ae7.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031539.jpg_44b53a5d-0adc-4af4-bf88-28770673bd74.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031539.jpg_5bbe3ab6-16bd-4548-9acc-686cd4b54bf7.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031569.jpg_6939c0ba-6d8c-407f-baae-ec22f79e1dee.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031585.jpg_10c1b238-e1f7-4e3d-b73b-e479a94cbc07.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031585.jpg_11d839e0-068f-4c4b-80eb-e2944d8cb58f.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031614.jpg_62920853-825d-49d0-81c0-b6ccfe2a7454.jpg',
#  'images\\Train\\basal cell carcinoma\\output\\basal cell carcinoma_original_ISIC_0031614.jpg_f12d78ab-0da3-437d-82f0-4b9d12152ffb.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
for i in class_names:
    directory ='images/Train'
    directory_out ='images/Train'+'/'+i+'/output/'
    class_directory = pathlib.Path(directory)
    class_directory_out = pathlib.Path(directory_out)
    length=len(list(class_directory.glob(i+'/*.jpg')))
    length_out=len(list(class_directory_out.glob('*.jpg')))
    length_tot=length+length_out
    print(f'{i} has {length_tot} samples.')
# Out:
# actinic keratosis has 614 samples.
# basal cell carcinoma has 876 samples.
# dermatofibroma has 595 samples.
# melanoma has 938 samples.
# nevus has 857 samples.
# pigmented benign keratosis has 962 samples.
# seborrheic keratosis has 577 samples.
# squamous cell carcinoma has 681 samples.
# vascular lesion has 639 samples.

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train="images/Train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
model = Sequential()
model.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3))) 
model.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Conv2D(256,kernel_size=(11,11),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Dropout(0.5))
model.add(layers.Flatten())
model.add(layers.Dense(256,activation='relu'))
model.add(layers.Dropout(0.25))
model.add(layers.Dense(128,activation='relu'))
model.add(layers.Dropout(0.25))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dropout(0.25))
model.add(layers.Dense(len(class_names),activation='softmax'))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
### Todo, choose an appropirate optimiser and loss function
learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-7)
opt=tf.keras.optimizers.Adam()
model.compile(optimizer=opt,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_7 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 178, 178, 32)      896
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 89, 89, 32)        0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 87, 87, 64)        18496
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 43, 43, 64)        0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 41, 41, 128)       73856
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 20, 20, 128)       0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 10, 10, 256)       3965184
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 256)               1638656
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 9)                 585
# =================================================================
# Total params: 5,738,825
# Trainable params: 5,738,825
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Epoch 38/50
# 169/169 [==============================] - 9s 52ms/step - loss: 0.4888 - accuracy: 0.8151 - val_loss: 0.5858 - val_accuracy: 0.7906
# Epoch 39/50
# 169/169 [==============================] - 9s 52ms/step - loss: 0.4737 - accuracy: 0.8268 - val_loss: 0.5016 - val_accuracy: 0.8337
# Epoch 40/50
# 169/169 [==============================] - 9s 52ms/step - loss: 0.4575 - accuracy: 0.8340 - val_loss: 0.5193 - val_accuracy: 0.8085
# Epoch 41/50
# 169/169 [==============================] - 9s 52ms/step - loss: 0.4326 - accuracy: 0.8349 - val_loss: 0.4294 - val_accuracy: 0.8523
# Epoch 42/50
# 169/169 [==============================] - 9s 52ms/step - loss: 0.4322 - accuracy: 0.8407 - val_loss: 0.4927 - val_accuracy: 0.8344
# Epoch 43/50
# 169/169 [==============================] - 9s 52ms/step - loss: 0.4225 - accuracy: 0.8446 - val_loss: 0.4346 - val_accuracy: 0.8486
# Epoch 44/50
# 169/169 [==============================] - 9s 52ms/step - loss: 0.4962 - accuracy: 0.8244 - val_loss: 0.4817 - val_accuracy: 0.8382
# Epoch 45/50
# 169/169 [==============================] - 9s 52ms/step - loss: 0.3850 - accuracy: 0.8585 - val_loss: 0.4689 - val_accuracy: 0.8382
# Epoch 46/50
# 169/169 [==============================] - 9s 52ms/step - loss: 0.3925 - accuracy: 0.8540 - val_loss: 0.4589 - val_accuracy: 0.8359
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 47/50
# 169/169 [==============================] - 9s 52ms/step - loss: 0.2992 - accuracy: 0.8865 - val_loss: 0.3840 - val_accuracy: 0.8716
# Epoch 48/50
# 169/169 [==============================] - 9s 53ms/step - loss: 0.2592 - accuracy: 0.8961 - val_loss: 0.3826 - val_accuracy: 0.8723
# Epoch 49/50
# 169/169 [==============================] - 9s 52ms/step - loss: 0.2727 - accuracy: 0.8961 - val_loss: 0.3820 - val_accuracy: 0.8790
# Epoch 50/50
# 169/169 [==============================] - 9s 53ms/step - loss: 0.2454 - accuracy: 0.9060 - val_loss: 0.3907 - val_accuracy: 0.8768

# %% [markdown]
# #### **Todo:** Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:** Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# **Findings**
# 1. The training accuracy and validation accuracy are almost same. This is a sign of good fit.
# 2. The training loss and validation loss are almost same. This is a sign of good fit.
# 3. The Validation accuracy is 0.87 which is good. The model is able to classify the images with 87% accuracy.

# %% [markdown]
# ### Test the model

# %%
from glob import glob
from tensorflow.keras.preprocessing.image import load_img, img_to_array
Test_image_path = os.path.join(data_dir_test, class_names[1], '*')
Test_image = glob(Test_image_path)
Test_image = load_img(Test_image[-1],target_size=(180,180,3))
plt.imshow(Test_image)
plt.grid(False)

img = np.expand_dims(Test_image,axis=0)
pred = model.predict(img)
pred = np.argmax(pred)
pred_class = class_names[pred]
print(f"Actual Class: {class_names[1]}" + '\n' + "Predictive Class: " + pred_class)
# Out:
# Actual Class: basal cell carcinoma
# Predictive Class: basal cell carcinoma
